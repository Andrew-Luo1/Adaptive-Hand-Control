# %% [markdown]
# ## Import

# %%
import numpy as np
a = np.load('test_results/adapting-23-23:2.npy')
actual_path = a[0]
target_path = a[1]
times = a[2]

# %% [markdown]
# ## Evaluate

# %% [markdown]
# #### Things to change:
# - number of neurons
# - tau_ref and tau_rc
# - including inverter ensemble

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Metrics: Target Position and 
plt.plot(target_path)
plt.legend(('motor 1', 'motor 2', 'motor 3', 'motor 4'))

plt.figure()
plt.plot(actual_path)
plt.legend(('motor 1', 'motor 2', 'motor 3', 'motor 4'))

# %%
#Metrics: Error
plt.plot(target_path-actual_path)
plt.legend(('motor 1', 'motor 2', 'motor 3', 'motor 4'))
